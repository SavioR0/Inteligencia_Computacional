# %% [markdown]
# # **Import das bibliotecas utilizadas**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
from pylab import plot, show, legend, title, xlabel, ylabel, axis
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/usd_coin.csv")
print(data.head())
# Out:
#    Ultimo  Abertura  Maxima  Minima  Ultimo_2  Abertura_2  Maxima_2  Minima_2  \
# 0  1.0127    0.9848  1.0165  0.9829    1.0013      1.0127    1.0317    0.9939
# 1  1.0013    1.0127  1.0317  0.9939    1.0022      1.0013    1.0150    0.9913
# 2  1.0022    1.0013  1.0150  0.9913    0.9913      1.0022    1.0099    0.9906
# 3  0.9913    1.0022  1.0099  0.9906    0.9950      0.9913    1.0001    0.9895
# 4  0.9950    0.9913  1.0001  0.9895    0.9926      0.9950    0.9986    0.9864
#
#    Ultimo_3  Abertura_3  Maxima_3  Minima_3  Dia_seguinte
# 0    1.0022      1.0013    1.0150    0.9913        0.9913
# 1    0.9913      1.0013    1.0099    0.9906        0.9950
# 2    0.9950      0.9913    1.0001    0.9895        0.9926
# 3    0.9926      0.9950    0.9986    0.9864        0.9952
# 4    0.9952      0.9926    1.0000    0.9867        1.0006

# %% [markdown]
# # **Análise dos dados**

# %%
plt.figure(figsize=(10, 4))
plt.title("USD - Variação da taxa de câmbio")
plt.ylabel("Fechamento")
plt.xlabel("Tempo")
plt.plot(data["Ultimo"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#                 Ultimo  Abertura    Maxima    Minima  Ultimo_2  Abertura_2  \
# Ultimo        1.000000  0.345136  0.268536  0.240638  0.495389    0.998904
# Abertura      0.345136  1.000000  0.281366  0.239724  0.300189    0.344905
# Maxima        0.268536  0.281366  1.000000 -0.130728  0.095804    0.267891
# Minima        0.240638  0.239724 -0.130728  1.000000  0.138480    0.241111
# Ultimo_2      0.495389  0.300189  0.095804  0.138480  1.000000    0.491932
# Abertura_2    0.998904  0.344905  0.267891  0.241111  0.491932    1.000000
# Maxima_2      0.342137  0.049465  0.365801 -0.117250  0.246112    0.340032
# Minima_2      0.224325  0.116635 -0.172516  0.413359  0.284109    0.222317
# Ultimo_3      0.331168  0.222014  0.016052  0.139848  0.508201    0.332010
# Abertura_3    0.494344  0.293823  0.088194  0.139086  0.998552    0.490479
# Maxima_3      0.140943  0.033094  0.172322 -0.107746  0.292667    0.136683
# Minima_3      0.108240  0.053961 -0.175828  0.294268  0.244498    0.114462
# Dia_seguinte  0.260940  0.279142 -0.003011  0.215177  0.329569    0.257244
#
#               Maxima_2  Minima_2  Ultimo_3  Abertura_3  Maxima_3  Minima_3  \
# Ultimo        0.342137  0.224325  0.331168    0.494344  0.140943  0.108240
# Abertura      0.049465  0.116635  0.222014    0.293823  0.033094  0.053961
# Maxima        0.365801 -0.172516  0.016052    0.088194  0.172322 -0.175828
# Minima       -0.117250  0.413359  0.139848    0.139086 -0.107746  0.294268
# Ultimo_2      0.246112  0.284109  0.508201    0.998552  0.292667  0.244498
# Abertura_2    0.340032  0.222317  0.332010    0.490479  0.136683  0.114462
# Maxima_2      1.000000 -0.120887  0.091923    0.243452  0.350369 -0.170461
# Minima_2     -0.120887  1.000000  0.143494    0.285518 -0.098073  0.412949
# Ultimo_3      0.091923  0.143494  1.000000    0.509325  0.243807  0.285922
# Abertura_3    0.243452  0.285518  0.509325    1.000000  0.289469  0.243502
# Maxima_3      0.350369 -0.098073  0.243807    0.289469  1.000000 -0.117709
# Minima_3     -0.170461  0.412949  0.285922    0.243502 -0.117709  1.000000
# Dia_seguinte  0.009036  0.147141  0.507847    0.333197  0.079979  0.146050
#
#               Dia_seguinte
# Ultimo            0.260940
# Abertura          0.279142
# Maxima           -0.003011
# Minima            0.215177
# Ultimo_2          0.329569
# Abertura_2        0.257244
# Maxima_2          0.009036
# Minima_2          0.147141
# Ultimo_3          0.507847
# Abertura_3        0.333197
# Maxima_3          0.079979
# Minima_3          0.146050
# Dia_seguinte      1.000000

# %% [markdown]
# # **Definindo varáveis para o cálculo**

# %% [markdown]
# ## Base aleatória

# %%
x_a = data[["Abertura_2","Ultimo_2","Ultimo_3","Minima_2","Abertura","Abertura_3","Ultimo","Minima_3","Minima","Maxima_2"]]
y_a = data["Dia_seguinte"]
x_a = x_a.to_numpy()
y_a = y_a.to_numpy()
y_a = y_a.reshape(-1, 1)

# %% [markdown]
# ## Base ordenada

# %%
x_o = data[["Ultimo_3", "Ultimo_2", "Abertura_3"]]
y_o = data["Dia_seguinte"]
x_o = x_o.to_numpy()
y_o = y_o.to_numpy()
y_o = y_o.reshape(-1, 1)

# %% [markdown]
# # **Aplicando árvores de decisões às bases ordenadas e aleatórias**

# %%
test_number = 0.2
x_a_train, x_a_test, y_a_train, y_a_test = train_test_split(x_a, y_a, test_size=test_number, random_state=42)
x_o_train, x_o_test, y_o_train, y_o_test = train_test_split(x_o, y_o, test_size=test_number, random_state=42)


model_a = DecisionTreeRegressor()
model_a.fit(x_a_train, y_a_train)
ypred_a = model_a.predict(x_a_test)

model_o = DecisionTreeRegressor()
model_o.fit(x_o_train, y_o_train)
ypred_o = model_o.predict(x_o_test)

# %% [markdown]
# ## Exibição dos resultados obtidos

# %%
data_a = pd.DataFrame(data={"Resultados obtidos base aleatória": ypred_a.flatten()})
data_o = pd.DataFrame(data={"Resultados obtidos base ordenada": ypred_o.flatten()})
print(data_a)
print(data_o)
# Out:
#      Resultados obtidos base aleatória
# 0                               0.9996
# 1                               1.0007
# 2                               0.9972
# 3                               1.0001
# 4                               1.0003
# ..                                 ...
# 214                             0.9999
# 215                             0.9991
# 216                             1.0014
# 217                             1.0000
# 218                             0.9971
#
# [219 rows x 1 columns]
#      Resultados obtidos base ordenada
# 0                            1.000900
# 1                            0.998900
# 2                            0.999000
# 3                            1.000000
# 4                            0.999800
# ..                                ...
# 214                          0.999540
# 215                          0.999891
# 216                          1.000200
# 217                          0.999517
# 218                          1.000600
#
# [219 rows x 1 columns]

# %% [markdown]
# # **Calclulando o erro com base no resultado obtido e no resultado esperado**

# %%
error_a = y_a - ypred_a
error_o = y_o - ypred_o

average_a = sum(error_a[0])/len(error_a[0]) # Média
average_o = sum(error_o[0])/len(error_o[0]) # Média

error_a = pd.DataFrame(data={"Erro aleatório": error_a.flatten()})
error_o = pd.DataFrame(data={"Erro ordenado": error_o.flatten()})


print(error_a.head())
print(error_o.head())

print("\n\nMédia dos erros aleatórios: ", average_a)
print("Média dos erros ordenados: ", average_o)
print("Diferença: ", average_a - average_o)
# Out:
#    Erro aleatório
# 0         -0.0083
# 1         -0.0094
# 2         -0.0059
# 3         -0.0088
# 4         -0.0090
#    Erro ordenado
# 0        -0.0096
# 1        -0.0076
# 2        -0.0077
# 3        -0.0087
# 4        -0.0085
#
#
# Média dos erros aleatórios:  -0.00841050228310506
# Média dos erros ordenados:  -0.008382950229628363
# Diferença:  -2.755205347669716e-05

# %%
Target = y_a[0:219]
Predicted = ypred_a
plt.title("Erro base aleatória X objetivo")
plt.plot(Target, label= "Objetivo")
plt.plot(Predicted, label= "Previsto")
plt.legend()
plt.show()

Target = y_o[0:219]
Predicted = ypred_o
plt.title("Erro base ordenada X objetivo")
plt.plot(Target, label= "Objetivo")
plt.plot(Predicted, label= "Previsto")
plt.legend()
plt.show()

# %%
plt.plot(ypred_o, label= "Erro na base Ordenada")
plt.plot(ypred_a, label= "Erro na base Aleatória")
plt.title("Comparação dos error obtidos")
plt.ylabel("Erro com relação ao esperado")
plt.xlabel("Linha da base de dados")
plt.legend()
plt.show()
